# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "https://tennis-data-wta-atp.s3-us-west-2.amazonaws.com/wta/2019.xlsx"
df = pd.read_excel(path)

# %%
df = df.iloc[:, :24 ]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2472 entries, 0 to 2471
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   WTA         2472 non-null   int64
#  1   Location    2472 non-null   object
#  2   Tournament  2472 non-null   object
#  3   Date        2472 non-null   datetime64[ns]
#  4   Tier        2472 non-null   object
#  5   Court       2472 non-null   object
#  6   Surface     2472 non-null   object
#  7   Round       2472 non-null   object
#  8   Best of     2472 non-null   int64
#  9   Winner      2472 non-null   object
#  10  Loser       2472 non-null   object
#  11  WRank       2467 non-null   float64
#  12  LRank       2464 non-null   float64
#  13  WPts        2467 non-null   float64
#  14  LPts        2464 non-null   float64
#  15  W1          2461 non-null   float64
#  16  L1          2461 non-null   float64
#  17  W2          2436 non-null   float64
# ...

# %%
pd.get_dummies(df, columns=["Tier","Court","Surface","Comment"])
# Out:
#       WTA  Location   Tournament       Date        Round  Best of  \
# 0       1  Auckland  ASB Classic 2018-12-31    1st Round        3
# 1       1  Auckland  ASB Classic 2018-12-31    1st Round        3
# 2       1  Auckland  ASB Classic 2018-12-31    1st Round        3
# 3       1  Auckland  ASB Classic 2018-12-31    1st Round        3
# 4       1  Auckland  ASB Classic 2018-12-31    1st Round        3
# ...   ...       ...          ...        ...          ...      ...
# 2467   58  Shenzhen   WTA Finals 2019-11-01  Round Robin        3
# 2468   58  Shenzhen   WTA Finals 2019-11-01  Round Robin        3
# 2469   58  Shenzhen   WTA Finals 2019-11-02   Semifinals        3
# 2470   58  Shenzhen   WTA Finals 2019-11-02   Semifinals        3
# 2471   58  Shenzhen   WTA Finals 2019-11-03    The Final        3
#
#                  Winner            Loser  WRank  LRank  ...  Tier_Premier  \
# 0               Puig M.  Mattek-Sands B.   53.0  350.0  ...             0
# ...
