# %%
import pandas as pd
import glob
import boto3
import s3fs

# %%
path = "https://ford-data-public.s3-us-west-2.amazonaws.com/atp_matches/{}".format(path)
# Out:
# 'https://ford-data-public.s3-us-west-2.amazonaws.com/atp_matches/*'

# %%
atp_files = ['atp_matches_2000.csv',
'atp_matches_2001.csv',
'atp_matches_2002.csv',
'atp_matches_2003.csv',
'atp_matches_2004.csv',
'atp_matches_2005.csv',
'atp_matches_2006.csv',
'atp_matches_2007.csv',
'atp_matches_2008.csv',
'atp_matches_2009.csv',
'atp_matches_2010.csv',
'atp_matches_2011.csv',
'atp_matches_2012.csv',
'atp_matches_2013.csv',
'atp_matches_2014.csv',
'atp_matches_2015.csv',
'atp_matches_2016.csv',
'atp_matches_2017.csv']

# %%
atp_files
# Out:
# ['atp_matches_2000.csv',
#  'atp_matches_2001.csv',
#  'atp_matches_2002.csv',
#  'atp_matches_2003.csv',
#  'atp_matches_2004.csv',
#  'atp_matches_2005.csv',
#  'atp_matches_2006.csv',
#  'atp_matches_2007.csv',
#  'atp_matches_2008.csv',
#  'atp_matches_2009.csv',
#  'atp_matches_2010.csv',
#  'atp_matches_2011.csv',
#  'atp_matches_2012.csv',
#  'atp_matches_2013.csv',
#  'atp_matches_2014.csv',
#  'atp_matches_2015.csv',
#  'atp_matches_2016.csv',
#  'atp_matches_2017.csv']

# %%
atp_list = []
for i in atp_files:
    path = "https://ford-data-public.s3-us-west-2.amazonaws.com/atp_matches/{}".format(i)
    pd.read_csv(path))

# %%
pd.DataFrame(atp_list)
# Out:
#                                                     0
# 0        tourney_id                 tourney_name s...
# 1        tourney_id                 tourney_name s...
# 2        tourney_id                 tourney_name s...
# 3        tourney_id                 tourney_name s...
# 4        tourney_id                 tourney_name s...
# 5        tourney_id                 tourney_name s...
# 6        tourney_id                 tourney_name s...
# 7        tourney_id                 tourney_name s...
# 8        tourney_id                 tourney_name s...
# 9        tourney_id                 tourney_name s...
# 10       tourney_id                 tourney_name s...
# 11       tourney_id                 tourney_name s...
# 12       tourney_id                 tourney_name s...
# 13       tourney_id                 tourney_name s...
# 14       tourney_id                 tourney_name s...
# 15       tourney_id                 tourney_name s...
# 16                                                ...
# 17                                                ...

# %%
pd.concat(atp_list)
# Out:
#                                                            tourney_id  \
# 0                                                            2000-717
# 1                                                            2000-717
# 2                                                            2000-717
# 3                                                            2000-717
# 4                                                            2000-717
# ...                                                               ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...     Nenad Zimonjic
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  Marco Chiudinelli
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    Henri Laaksonen
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...      Adrien Bossel
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    Antoine Bellier
#
#                                                    tourney_name surface  \
# 0                                                       Orlando    Clay
# 1                                                       Orlando    Clay
# 2                                                       Orlando    Clay
# 3                                                       Orlando    Clay
# 4                                                       Orlando    Clay
# ...                                                         ...     ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...            R     190
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...            R     185
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...            R     NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...            L     NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...            U     NaN
#
#                                                    draw_size tourney_level  \
# 0                                                         32             A
# 1                                                         32             A
# 2                                                         32             A
# 3                                                         32             A
# 4                                                         32             A
# ...                                                      ...           ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...       SRB       40.6571
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       SUI       35.3895
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       SUI        24.835
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       SUI       30.0917
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       SUI       20.2847
#
#                                                     tourney_date  match_num  \
# 0                                                     20000501.0        1.0
# 1                                                     20000501.0        2.0
# 2                                                     20000501.0        3.0
# 3                                                     20000501.0        4.0
# 4                                                     20000501.0        5.0
# ...                                                          ...        ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...           NaN        NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...         146.0      414.0
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...         127.0      473.0
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...         485.0       78.0
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...         598.0       52.0
#
#                                                              winner_id  \
# 0                                                               102179
# 1                                                               103602
# 2                                                               103387
# 3                                                               101733
# 4                                                               101727
# ...                                                                ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...            Walkover
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...         6-4 6-3 6-1
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  4-6 6-2 6-2 7-6(1)
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...             6-3 7-5
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...             6-4 6-3
#
#                                                     winner_seed winner_entry  \
# 0                                                           NaN          NaN
# 1                                                           NaN            Q
# 2                                                           NaN          NaN
# 3                                                           NaN          NaN
# 4                                                           4.0          NaN
# ...                                                         ...          ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...          3.0           RR
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...          5.0           RR
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...          5.0           RR
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...          3.0           RR
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...          3.0           RR
#
#                                                     ... w_bpFaced l_ace  l_df  \
# 0                                                   ...      15.0  13.0   4.0
# 1                                                   ...       6.0   0.0   0.0
# 2                                                   ...       0.0   2.0   2.0
# 3                                                   ...      12.0   4.0   6.0
# 4                                                   ...       1.0   0.0   3.0
# ...                                                 ...       ...   ...   ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...  ...       NaN   NaN   NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  ...       NaN   NaN   NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  ...       NaN   NaN   NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  ...       NaN   NaN   NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...  ...       NaN   NaN   NaN
#
#                                                    l_svpt  l_1stIn  l_1stWon  \
# 0                                                   110.0     59.0      49.0
# 1                                                    57.0     24.0      13.0
# 2                                                    65.0     39.0      22.0
# 3                                                   104.0     57.0      35.0
# 4                                                    47.0     28.0      17.0
# ...                                                   ...      ...       ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...    NaN      NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    NaN      NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    NaN      NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    NaN      NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...    NaN      NaN       NaN
#
#                                                     l_2ndWon  l_SvGms  \
# 0                                                       31.0     17.0
# 1                                                       17.0     10.0
# 2                                                       10.0      8.0
# 3                                                       24.0     15.0
# 4                                                       10.0      8.0
# ...                                                      ...      ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...       NaN      NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       NaN      NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       NaN      NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       NaN      NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...       NaN      NaN
#
#                                                     l_bpSaved l_bpFaced
# 0                                                         4.0       4.0
# 1                                                         4.0       9.0
# 2                                                         6.0      10.0
# 3                                                         6.0      11.0
# 4                                                         3.0       6.0
# ...                                                       ...       ...
# (2017-M-DC-2017-WG-M-RUS-SRB-01, Davis Cup WG R...        NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...        NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...        NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...        NaN       NaN
# (2017-M-DC-2017-WG-M-SUI-USA-01, Davis Cup WG R...        NaN       NaN
#
# [53571 rows x 49 columns]

# %%
wta_matches = [
'wta_matches_2001.csv',
'wta_matches_2002.csv',
'wta_matches_2003.csv',
'wta_matches_2004.csv',
'wta_matches_2005.csv',
'wta_matches_2006.csv',
'wta_matches_2007.csv',
'wta_matches_2008.csv',
'wta_matches_2009.csv',
'wta_matches_2010.csv',
'wta_matches_2011.csv',
'wta_matches_2012.csv',
'wta_matches_2013.csv',
'wta_matches_2014.csv',
'wta_matches_2015.csv',
'wta_matches_2016.csv']

# %%
path = "https://ford-data-public.s3-us-west-2.amazonaws.com/wta_matches/wta_matches_2000.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                tourney_id     tourney_name surface  draw_size tourney_level  \
# 0  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 1  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 2  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 3  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 4  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
#
#    tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 0      20000117          1     200001          1.0          NaN  ...
# 1      20000117          2     200003          NaN          NaN  ...
# 2      20000117          3     200006          NaN          NaN  ...
# 3      20000117          4     200008          NaN          NaN  ...
# 4      20000117          5     200009          NaN          NaN  ...
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0          Mirjana Lucic          R       NaN       CRO  17.859001
# 1        Kerry Anne Guse          R       NaN       AUS  27.118412
# 2  Jolene Watanabe Giltz          R       NaN       USA  31.378508
# 3         Silvija Talaja          R       NaN       CRO  22.006845
# 4            Rita Grande          R       NaN       ITA  24.821355
#
#    loser_rank  loser_rank_points        score  best_of round
# 0        49.0              640.0      6-1 6-2        3  R128
# 1       133.0              199.0      6-4 6-2        3  R128
# 2       118.0              243.0      6-0 6-1        3  R128
# 3        23.0             1112.0  6-1 5-7 7-5        3  R128
# 4        60.0              516.0      6-3 6-4        3  R128
#
# [5 rows x 30 columns]

# %%
df.count()
# Out:
# tourney_id            2893
# tourney_name          2893
# surface               2893
# draw_size             2893
# tourney_level         2893
# tourney_date          2893
# match_num             2893
# winner_id             2893
# winner_seed           1134
# winner_entry           317
# winner_name           2893
# winner_hand           2819
# winner_ht             1027
# winner_ioc            2893
# winner_age            2893
# winner_rank           2709
# winner_rank_points    2709
# loser_id              2893
# loser_seed             555
# loser_entry            554
# loser_name            2893
# loser_hand            2724
# loser_ht               643
# loser_ioc             2893
# loser_age             2893
# loser_rank            2602
# loser_rank_points     2602
# score                 2893
# best_of               2893
# round                 2893
# dtype: int64

# %%
for i in wta_matches:
    path = "https://ford-data-public.s3-us-west-2.amazonaws.com/wta_matches/{}".format(i)
    j = pd.read_csv(path, header=None, encoding='ISO-8859-1')
    df.append(j)

# %%
df.count()
# Out:
# tourney_id            2893
# tourney_name          2893
# surface               2893
# draw_size             2893
# tourney_level         2893
# tourney_date          2893
# match_num             2893
# winner_id             2893
# winner_seed           1134
# winner_entry           317
# winner_name           2893
# winner_hand           2819
# winner_ht             1027
# winner_ioc            2893
# winner_age            2893
# winner_rank           2709
# winner_rank_points    2709
# loser_id              2893
# loser_seed             555
# loser_entry            554
# loser_name            2893
# loser_hand            2724
# loser_ht               643
# loser_ioc             2893
# loser_age             2893
# loser_rank            2602
# loser_rank_points     2602
# score                 2893
# best_of               2893
# round                 2893
# dtype: int64

# %%
# !pwd
# Out:
# /Users/marvinford

# %%
path1 = "/Users/marvinford/atp/"

# %%
pd.read_excel(path1)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-69-ed2e19efb4cb> in <module>
# ----> 1 pd.read_excel(path1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# IsADirectoryError: [Errno 21] Is a directory: '/Users/marvinford/atp/'

# %%
path3 = "https://tennis-data-wta-atp.s3-us-west-2.amazonaws.com/atp/"

# %%
pd.read_excel(path3)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-72-b8c68774c9be> in <module>
# ----> 1 pd.read_excel(path3)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
#     825
#     826     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     340         # If filepath_or_buffer is a url, load the data into a BytesIO
#     341         if is_url(filepath_or_buffer):
# --> 342             filepath_or_buffer = BytesIO(urlopen(filepath_or_buffer).read())
#     343         elif not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
#     344             filepath_or_buffer, _, _, _ = get_filepath_or_buffer(filepath_or_buffer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
path = "s3://tennis-data-wta-atp/atp/2000.xls"
df = pd.read_excel(path)
df.head()
# Out:
#    ATP  Location                          Tournament       Date  \
# 0    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 1    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 2    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 3    1  Adelaide  Australian Hardcourt Championships 2000-01-03
# 4    1  Adelaide  Australian Hardcourt Championships 2000-01-03
#
#           Series    Court Surface      Round  Best of       Winner  ...   L2  \
# 0  International  Outdoor    Hard  1st Round        3   Dosedel S.  ...  2.0
# 1  International  Outdoor    Hard  1st Round        3   Enqvist T.  ...  3.0
# 2  International  Outdoor    Hard  1st Round        3    Escude N.  ...  5.0
# 3  International  Outdoor    Hard  1st Round        3   Federer R.  ...  4.0
# 4  International  Outdoor    Hard  1st Round        3  Fromberg R.  ...  7.0
#
#     W3   L3  W4  L4  W5  L5  Wsets  Lsets    Comment
# 0  NaN  NaN NaN NaN NaN NaN      2      0  Completed
# 1  NaN  NaN NaN NaN NaN NaN      2      0  Completed
# 2  6.0  3.0 NaN NaN NaN NaN      2      1  Completed
# 3  NaN  NaN NaN NaN NaN NaN      2      0  Completed
# 4  6.0  4.0 NaN NaN NaN NaN      2      1  Completed
#
# [5 rows x 26 columns]
